# %%
import qiskit
import pytket
from matplotlib import pyplot as plt

# %% [markdown]
# First create the circuit

# %%
from qiskit.aqua.algorithms import Grover
from qiskit.aqua.components.oracles import TruthTableOracle

oracle = TruthTableOracle('0100')
grover = Grover(oracle)
circuit = grover.construct_circuit(measurement= True)

# %%
circuit.draw('mpl')

# %% [markdown]
# Convert the circuit to tket

# %%
from pytket.qiskit import qiskit_to_tk
circuit = qiskit_to_tk(circuit)

# %%
circuit
# Out:
# [U3(1*PI, 0*PI, 1*PI) o[0]; U2(0*PI, 1*PI) v[0]; U2(0*PI, 1*PI) v[1]; U2(0*PI, 1*PI) o[0]; X v[1]; CCX v[0], v[1], o[0]; X v[1]; Barrier v[0], v[1]; U2(0*PI, 1*PI) v[0]; U2(0*PI, 1*PI) v[1]; U3(1*PI, 0*PI, 1*PI) v[0]; U3(1*PI, 0*PI, 1*PI) v[1]; U2(0*PI, 1*PI) v[1]; CX v[0], v[1]; U3(1*PI, 0*PI, 1*PI) v[0]; U2(0*PI, 1*PI) v[1]; U2(0*PI, 1*PI) v[0]; U3(1*PI, 0*PI, 1*PI) v[1]; U2(0*PI, 1*PI) v[1]; Barrier v[0], v[1]; Measure v[0] --> m[0]; Measure v[1] --> m[1]; ]

# %%
from pytket.utils import Graph
Graph(circuit).get_DAG()

# %%
from pytket.backends.ibm import IBMQBackend
backend = IBMQBackend("ibmq_qasm_simulator");

# %%
backend.compile_circuit(circuit)

# %%
Graph(circuit).get_DAG()

# %%
from pytket.qasm import circuit_to_qasm_str, circuit_from_qasm_str
qasm = circuit_to_qasm_str(circuit)
qasm = qasm.replace('FCNode', 'node')
circuit = circuit_from_qasm_str(qasm)

# %%
Graph(circuit).get_DAG()

# %%
job = backend.process_circuit(circuit, n_shots=1000, valid_check= False)
# Out:
# ---------------------------------------------------------------------------
# CircuitNotValidError                      Traceback (most recent call last)
# <ipython-input-27-87aaeebb68b9> in <module>
# ----> 1 job = backend.process_circuit(circuit, n_shots=1000)
#
# ~/anaconda3/envs/planqk/lib/python3.7/site-packages/pytket/backends/backend.py in process_circuit(self, circuit, n_shots, valid_check, **kwargs)
#     175         """
#     176         return self.process_circuits(
# --> 177             [circuit], n_shots=n_shots, valid_check=valid_check, **kwargs
#     178         )[0]
#     179
#
# ~/anaconda3/envs/planqk/lib/python3.7/site-packages/pytket/backends/ibm/ibm.py in process_circuits(self, circuits, n_shots, valid_check, **kwargs)
#     244             filtchunk = list(filter(lambda x: x is not None, chunk))
#     245             if valid_check:
# --> 246                 self._check_all_circuits(filtchunk)
#     247             qcs = [tk_to_qiskit(tkc) for tkc in filtchunk]
#     248             qobj = assemble(qcs, shots=n_shots, memory=self._config.memory)
#
# ~/anaconda3/envs/planqk/lib/python3.7/site-packages/pytket/backends/backend.py in _check_all_circuits(self, circuts, nomeasure_warn)
#      90             )
#      91             for error in errors:
# ---> 92                 raise error
#      93             if nomeasure_warn:
#      94                 if circ.n_gates_of_type(OpType.Measure) < 1:
#
# CircuitNotValidError: Circuit with index 0 in submitted does not satisfy DirectednessPredicate:{ Nodes: 32, Edges: 992 } (try running backend.compile_circuit(circuit) first).

# %%
job
# Out:
# ResultHandle('5fb652e257ed400019dc23f3', 0)

# %%
status = backend.circuit_status(job)

# %%
status
# Out:
# CircuitStatus(status=<StatusEnum.SUBMITTED: 'Circuit has been submitted.'>, message='job is being validated')

# %%
result = backend.get_result(job)
# Out:
# Job Status: job has successfully run

# %%
result.get_counts()
# Out:
# Counter({(0, 0): 114, (0, 1): 84, (1, 0): 590, (1, 1): 212})
